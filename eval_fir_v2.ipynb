# %%
# !mkdir -p eval/out

# !yosys -q -p "read_verilog eval/fir/fir_n16_w8.v; proc; opt_merge; opt_clean; write_json eval/out/fir_n16_w8.json; synth_xilinx -family xcup; tee -o eval/out/fir_n16_w8.stat stat"

# %%
dsp_rules = {
    "dsp_generic": {
        "requirements": {
            "dsp48e2": 1
        },
        "hidden_inputs": ["clk"],
        "inputs": ["inputs"],
        "outputs": ["outputs"]
    }
}

# %%
import emap
import json

SCHEMA_PATH = "emap/schema.sql"

def simple_cost_model(type_: str, *ports) -> float:
    if type_ == "$dff":
        return len(ports[0]) * 1.0
    elif type_ in {"$muls", "$mulu"}:
        return len(ports[0]) * len(ports[1]) * 1.0
    elif type_ in {"$adds", "$addu", "$subs", "$subu"}:
        return min(len(ports[0]) + len(ports[1]), len(ports[2])) * 1.0
    return len(ports[0]) * 1.0  # other types

TEST_NAME = "fir_n16_w8"
netlist = emap.NetlistDB(SCHEMA_PATH)
with open(f"eval/out/{TEST_NAME}.json", "r") as f:
    netlist.build_from_json(json.load(f)["modules"]["top"])
netlist.rebuild()

cnt = 1
while cnt > 0:
    comm_matches = emap.rewrites.ematch_comm(netlist, ["$adds", "$muls"])
    dff_forward_aby_cell_matches = emap.rewrites.ematch_dff_forward_aby_cell(netlist, ["$adds", "$muls"])
    dff_backward_aby_cell_matches = emap.rewrites.ematch_dff_backward_aby_cell(netlist, ["$adds", "$muls"])

    cnt = emap.rewrites.apply_comm(netlist, comm_matches)
    cnt += emap.rewrites.apply_dff_forward_aby_cell(netlist, dff_forward_aby_cell_matches)
    cnt += emap.rewrites.apply_dff_backward_aby_cell(netlist, dff_backward_aby_cell_matches)
    if cnt > 0:
        print(f"Applied {cnt} rewrites")
    else:
        print("No rewrites applied, stopping")
    netlist.rebuild()

# techmapping
# basis: multiplication
emap.rewrites.create_tech_tables(netlist, dsp_rules)
emap.rewrites.techmap_dsp(netlist)

mod = emap.extracts.ilp.extract_techmap_with_limit(netlist, simple_cost_model, dsp_rules, {"dsp48e2": 16}, solver_type='auto', OutputFlag=False)

with open(f"eval/out/{TEST_NAME}_extracted.json", "w") as f:
    json.dump({"creator": "nextmap", "modules": {"top": mod}}, f, indent=2)

# %%
# !yosys -q -p "read_json eval/out/fir_n16_w8_extracted.json; read_verilog eval/blackboxes/dsp_defs.v; synth_xilinx -family xcup; tee -o eval/out/fir_n16_w8_extracted.stat stat"

# %%
# !yosys -q -p "read_verilog eval/fir/fir_n16_w16.v; proc; opt_merge; opt_clean; write_json eval/out/fir_n16_w16.json; synth_xilinx -family xcup; tee -o eval/out/fir_n16_w16.stat stat"

# %%
import emap
import json

SCHEMA_PATH = "emap/schema.sql"

def simple_cost_model(type_: str, *ports) -> float:
    if type_ == "$dff":
        return len(ports[0]) * 1.0
    elif type_ in {"$muls", "$mulu"}:
        return len(ports[0]) * len(ports[1]) * 1.0
    elif type_ in {"$adds", "$addu", "$subs", "$subu"}:
        return min(len(ports[0]) + len(ports[1]), len(ports[2])) * 1.0
    return len(ports[0]) * 1.0  # other types

TEST_NAME = "fir_n16_w16"
netlist = emap.NetlistDB(SCHEMA_PATH)
with open(f"eval/out/{TEST_NAME}.json", "r") as f:
    netlist.build_from_json(json.load(f)["modules"]["top"])
netlist.rebuild()

cnt = 1
while cnt > 0:
    comm_matches = emap.rewrites.ematch_comm(netlist, ["$adds", "$muls"])
    dff_forward_aby_cell_matches = emap.rewrites.ematch_dff_forward_aby_cell(netlist, ["$adds", "$muls"])
    dff_backward_aby_cell_matches = emap.rewrites.ematch_dff_backward_aby_cell(netlist, ["$adds", "$muls"])

    cnt = emap.rewrites.apply_comm(netlist, comm_matches)
    cnt += emap.rewrites.apply_dff_forward_aby_cell(netlist, dff_forward_aby_cell_matches)
    cnt += emap.rewrites.apply_dff_backward_aby_cell(netlist, dff_backward_aby_cell_matches)
    if cnt > 0:
        print(f"Applied {cnt} rewrites")
    else:
        print("No rewrites applied, stopping")
    netlist.rebuild()

# techmapping
# basis: multiplication
emap.rewrites.create_tech_tables(netlist, dsp_rules)
emap.rewrites.techmap_dsp(netlist)

mod = emap.extracts.ilp.extract_techmap_with_limit(netlist, simple_cost_model, dsp_rules, {"dsp48e2": 16}, solver_type='auto', OutputFlag=False)

with open(f"eval/out/{TEST_NAME}_extracted.json", "w") as f:
    json.dump({"creator": "nextmap", "modules": {"top": mod}}, f, indent=2)

# %%
# !yosys -q -p "read_json eval/out/fir_n16_w16_extracted.json; read_verilog eval/blackboxes/dsp_defs.v; synth_xilinx -family xcup; tee -o eval/out/fir_n16_w16_extracted.stat stat"

# %%
# !yosys -q -p "read_verilog eval/fir/fir_n16_w32.v; proc; opt_merge; opt_clean; write_json eval/out/fir_n16_w32.json; synth_xilinx -family xcup; tee -o eval/out/fir_n16_w32.stat stat"

# %%
import emap
import json

SCHEMA_PATH = "emap/schema.sql"

def simple_cost_model(type_: str, *ports) -> float:
    if type_ == "$dff":
        return len(ports[0]) * 1.0
    elif type_ in {"$muls", "$mulu"}:
        return len(ports[0]) * len(ports[1]) * 1.0
    elif type_ in {"$adds", "$addu", "$subs", "$subu"}:
        return min(len(ports[0]) + len(ports[1]), len(ports[2])) * 1.0
    return len(ports[0]) * 1.0  # other types

TEST_NAME = "fir_n16_w32"
netlist = emap.NetlistDB(SCHEMA_PATH)
with open(f"eval/out/{TEST_NAME}.json", "r") as f:
    netlist.build_from_json(json.load(f)["modules"]["top"])
netlist.rebuild()

matches = emap.rewrites.ematch_wide_muls(netlist)
cnt = emap.rewrites.apply_wide_muls_split(netlist, matches)
print(f"Applied {cnt} rewrites")
netlist.rebuild()
matches = emap.rewrites.ematch_wide_dff(netlist)
cnt = emap.rewrites.apply_wide_dff_split(netlist, matches)
print(f"Applied {cnt} rewrites")
netlist.rebuild()

cnt = 1
while cnt > 0:
    comm_matches = emap.rewrites.ematch_comm(netlist, ["$adds", "$muls"])
    dff_forward_aby_cell_matches = emap.rewrites.ematch_dff_forward_aby_cell(netlist, ["$adds", "$muls"])
    dff_backward_aby_cell_matches = emap.rewrites.ematch_dff_backward_aby_cell(netlist, ["$adds", "$muls"])

    cnt = emap.rewrites.apply_comm(netlist, comm_matches)
    cnt += emap.rewrites.apply_dff_forward_aby_cell(netlist, dff_forward_aby_cell_matches)
    cnt += emap.rewrites.apply_dff_backward_aby_cell(netlist, dff_backward_aby_cell_matches)
    if cnt > 0:
        print(f"Applied {cnt} rewrites")
    else:
        print("No rewrites applied, stopping")
    netlist.rebuild()

# techmapping
# basis: multiplication
emap.rewrites.create_tech_tables(netlist, dsp_rules)
emap.rewrites.techmap_dsp(netlist)

mod = emap.extracts.ilp.extract_techmap_with_limit(netlist, simple_cost_model, dsp_rules, {"dsp48e2": 48}, solver_type='auto', OutputFlag=False)

with open(f"eval/out/{TEST_NAME}_extracted.json", "w") as f:
    json.dump({"creator": "nextmap", "modules": {"top": mod}}, f, indent=2)
# Out:
# Found 80 cells
# Processing cell 0/80: $add$eval/fir/fir_n16_w32.v:56$10
# Database built with 4130 wires and global clock 2
# Applied 16 rewrites
# Applied 32 rewrites
# Applied 304 rewrites
# Applied 288 rewrites
# Applied 32 rewrites
# No rewrites applied, stopping
# C++ backend emapcc found
# Removed 288 dominated cells, 1328 remain
# C++ backend emapcc found
# Grouped 11492 wires into 388 groups
# ILP model solved with objective value: 7200.0

# %%
# !yosys -q -p "read_json eval/out/fir_n16_w32_extracted.json; read_verilog eval/blackboxes/dsp_defs.v; synth_xilinx -family xcup; tee -o eval/out/fir_n16_w32_extracted.stat stat"
# Out:
# Warning: Resizing cell port top.cell_96.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_96.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_97.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_97.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_98.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_98.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_99.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_99.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_100.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_100.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_101.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_101.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_102.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_102.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_103.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_103.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_104.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_104.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_105.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_105.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_106.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_106.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_107.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_107.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_108.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_108.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_109.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_109.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_110.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_110.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_111.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_111.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_112.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_112.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_113.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_113.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_114.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_114.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_115.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_115.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_116.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_116.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_117.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_117.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_118.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_118.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_119.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_119.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_120.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_120.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_121.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_121.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_122.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_122.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_123.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_123.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_124.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_124.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_125.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_125.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_126.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_126.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_127.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_127.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_128.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_128.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_129.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_129.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_130.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_130.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_131.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_131.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_132.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_132.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_133.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_133.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_134.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_134.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_135.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_135.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_136.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_136.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_137.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_137.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_138.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_138.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_139.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_139.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_140.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_140.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_141.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_141.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_142.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_142.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_143.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_143.outputs from 34 bits to 128 bits.

# %%
# !yosys -q -p "read_verilog eval/fir/fir_n32_w32.v; proc; opt_merge; opt_clean; write_json eval/out/fir_n32_w32.json; synth_xilinx -family xcup; tee -o eval/out/fir_n32_w32.stat stat"

# %%
import emap
import json

SCHEMA_PATH = "emap/schema.sql"

def simple_cost_model(type_: str, *ports) -> float:
    if type_ == "$dff":
        return len(ports[0]) * 1.0
    elif type_ in {"$muls", "$mulu"}:
        return len(ports[0]) * len(ports[1]) * 1.0
    elif type_ in {"$adds", "$addu", "$subs", "$subu"}:
        return min(len(ports[0]) + len(ports[1]), len(ports[2])) * 1.0
    return len(ports[0]) * 1.0  # other types

TEST_NAME = "fir_n32_w32"
netlist = emap.NetlistDB(SCHEMA_PATH)
with open(f"eval/out/{TEST_NAME}.json", "r") as f:
    netlist.build_from_json(json.load(f)["modules"]["top"])
netlist.rebuild()

matches = emap.rewrites.ematch_wide_muls(netlist)
cnt = emap.rewrites.apply_wide_muls_split(netlist, matches)
print(f"Applied {cnt} rewrites")
netlist.rebuild()
matches = emap.rewrites.ematch_wide_dff(netlist)
cnt = emap.rewrites.apply_wide_dff_split(netlist, matches)
print(f"Applied {cnt} rewrites")
netlist.rebuild()

cnt = 1
while cnt > 0:
    comm_matches = emap.rewrites.ematch_comm(netlist, ["$adds", "$muls"])
    dff_forward_aby_cell_matches = emap.rewrites.ematch_dff_forward_aby_cell(netlist, ["$adds", "$muls"])
    dff_backward_aby_cell_matches = emap.rewrites.ematch_dff_backward_aby_cell(netlist, ["$adds", "$muls"])

    cnt = emap.rewrites.apply_comm(netlist, comm_matches)
    cnt += emap.rewrites.apply_dff_forward_aby_cell(netlist, dff_forward_aby_cell_matches)
    cnt += emap.rewrites.apply_dff_backward_aby_cell(netlist, dff_backward_aby_cell_matches)
    if cnt > 0:
        print(f"Applied {cnt} rewrites")
    else:
        print("No rewrites applied, stopping")
    netlist.rebuild()

# techmapping
# basis: multiplication
emap.rewrites.create_tech_tables(netlist, dsp_rules)
emap.rewrites.techmap_dsp(netlist)

mod = emap.extracts.ilp.extract_techmap_with_limit(netlist, simple_cost_model, dsp_rules, {"dsp48e2": 96}, solver_type='auto', OutputFlag=False)

with open(f"eval/out/{TEST_NAME}_extracted.json", "w") as f:
    json.dump({"creator": "nextmap", "modules": {"top": mod}}, f, indent=2)
# Out:
# Found 160 cells
# Processing cell 0/160: $add$eval/fir/fir_n32_w32.v:56$10
# Database built with 8226 wires and global clock 2
# Applied 32 rewrites
# Applied 64 rewrites
# Applied 608 rewrites
# Applied 576 rewrites
# Applied 64 rewrites
# No rewrites applied, stopping
# C++ backend emapcc found
# Removed 576 dominated cells, 2656 remain
# C++ backend emapcc found
# Grouped 22948 wires into 772 groups
# ILP model solved with objective value: 14432.0

# %%
# !yosys -q -p "read_json eval/out/fir_n32_w32_extracted.json; read_verilog eval/blackboxes/dsp_defs.v; synth_xilinx -family xcup; tee -o eval/out/fir_n32_w32_extracted.stat stat"
# Out:
# Warning: Resizing cell port top.cell_192.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_192.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_193.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_193.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_194.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_194.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_195.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_195.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_196.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_196.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_197.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_197.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_198.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_198.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_199.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_199.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_200.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_200.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_201.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_201.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_202.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_202.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_203.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_203.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_204.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_204.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_205.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_205.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_206.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_206.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_207.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_207.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_208.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_208.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_209.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_209.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_210.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_210.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_211.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_211.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_212.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_212.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_213.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_213.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_214.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_214.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_215.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_215.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_216.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_216.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_217.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_217.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_218.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_218.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_219.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_219.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_220.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_220.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_221.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_221.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_222.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_222.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_223.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_223.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_224.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_224.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_225.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_225.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_226.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_226.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_227.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_227.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_228.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_228.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_229.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_229.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_230.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_230.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_231.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_231.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_232.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_232.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_233.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_233.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_234.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_234.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_235.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_235.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_236.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_236.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_237.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_237.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_238.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_238.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_239.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_239.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_240.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_240.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_241.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_241.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_242.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_242.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_243.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_243.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_244.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_244.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_245.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_245.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_246.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_246.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_247.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_247.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_248.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_248.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_249.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_249.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_250.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_250.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_251.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_251.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_252.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_252.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_253.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_253.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_254.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_254.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_255.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_255.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_256.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_256.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_257.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_257.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_258.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_258.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_259.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_259.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_260.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_260.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_261.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_261.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_262.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_262.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_263.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_263.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_264.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_264.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_265.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_265.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_266.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_266.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_267.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_267.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_268.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_268.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_269.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_269.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_270.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_270.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_271.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_271.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_272.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_272.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_273.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_273.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_274.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_274.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_275.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_275.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_276.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_276.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_277.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_277.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_278.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_278.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_279.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_279.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_280.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_280.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_281.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_281.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_282.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_282.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_283.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_283.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_284.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_284.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_285.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_285.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_286.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_286.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_287.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_287.outputs from 32 bits to 128 bits.

# %%
# !yosys -q -p "read_verilog eval/fir/fir_n64_w32.v; proc; opt_merge; opt_clean; write_json eval/out/fir_n64_w32.json; synth_xilinx -family xcup; tee -o eval/out/fir_n64_w32.stat stat"

# %%
import emap
import json

SCHEMA_PATH = "emap/schema.sql"

def simple_cost_model(type_: str, *ports) -> float:
    if type_ == "$dff":
        return len(ports[0]) * 1.0
    elif type_ in {"$muls", "$mulu"}:
        return len(ports[0]) * len(ports[1]) * 1.0
    elif type_ in {"$adds", "$addu", "$subs", "$subu"}:
        return min(len(ports[0]) + len(ports[1]), len(ports[2])) * 1.0
    return len(ports[0]) * 1.0  # other types

TEST_NAME = "fir_n64_w32"
netlist = emap.NetlistDB(SCHEMA_PATH)
with open(f"eval/out/{TEST_NAME}.json", "r") as f:
    netlist.build_from_json(json.load(f)["modules"]["top"])
netlist.rebuild()

matches = emap.rewrites.ematch_wide_muls(netlist)
cnt = emap.rewrites.apply_wide_muls_split(netlist, matches)
print(f"Applied {cnt} rewrites")
netlist.rebuild()
matches = emap.rewrites.ematch_wide_dff(netlist)
cnt = emap.rewrites.apply_wide_dff_split(netlist, matches)
print(f"Applied {cnt} rewrites")
netlist.rebuild()

cnt = 1
while cnt > 0:
    comm_matches = emap.rewrites.ematch_comm(netlist, ["$adds", "$muls"])
    dff_forward_aby_cell_matches = emap.rewrites.ematch_dff_forward_aby_cell(netlist, ["$adds", "$muls"])
    dff_backward_aby_cell_matches = emap.rewrites.ematch_dff_backward_aby_cell(netlist, ["$adds", "$muls"])

    cnt = emap.rewrites.apply_comm(netlist, comm_matches)
    cnt += emap.rewrites.apply_dff_forward_aby_cell(netlist, dff_forward_aby_cell_matches)
    cnt += emap.rewrites.apply_dff_backward_aby_cell(netlist, dff_backward_aby_cell_matches)
    if cnt > 0:
        print(f"Applied {cnt} rewrites")
    else:
        print("No rewrites applied, stopping")
    netlist.rebuild()

# techmapping
# basis: multiplication
emap.rewrites.create_tech_tables(netlist, dsp_rules)
emap.rewrites.techmap_dsp(netlist)

mod = emap.extracts.ilp.extract_techmap_with_limit(netlist, simple_cost_model, dsp_rules, {"dsp48e2": 192}, solver_type='auto', OutputFlag=False)

with open(f"eval/out/{TEST_NAME}_extracted.json", "w") as f:
    json.dump({"creator": "nextmap", "modules": {"top": mod}}, f, indent=2)
# Out:
# Found 320 cells
# Processing cell 0/320: $add$eval/fir/fir_n64_w32.v:56$10
# Database built with 16418 wires and global clock 2
# Applied 64 rewrites
# Applied 128 rewrites
# Applied 1216 rewrites
# Applied 1152 rewrites
# Applied 128 rewrites
# No rewrites applied, stopping
# C++ backend emapcc found
# Removed 1152 dominated cells, 5312 remain
# C++ backend emapcc found
# Grouped 45860 wires into 1540 groups
# ILP model solved with objective value: 28896.0

# %%
# !yosys -q -p "read_json eval/out/fir_n64_w32_extracted.json; read_verilog eval/blackboxes/dsp_defs.v; synth_xilinx -family xcup; tee -o eval/out/fir_n64_w32_extracted.stat stat"
# Out:
# Warning: Resizing cell port top.cell_384.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_384.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_385.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_385.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_386.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_386.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_387.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_387.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_388.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_388.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_389.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_389.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_390.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_390.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_391.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_391.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_392.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_392.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_393.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_393.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_394.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_394.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_395.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_395.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_396.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_396.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_397.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_397.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_398.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_398.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_399.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_399.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_400.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_400.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_401.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_401.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_402.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_402.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_403.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_403.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_404.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_404.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_405.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_405.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_406.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_406.outputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell_407.inputs from 81 bits to 128 bits.
# Warning: Resizing cell port top.cell_407.outputs from 34 bits to 128 bits.
# Warning: Resizing cell port top.cell_408.inputs from 32 bits to 128 bits.
# Warning: Resizing cell port top.cell